# %%
import asyncio
from crawl4ai import AsyncWebCrawler, CrawlerRunConfig,BrowserConfig,CacheMode

async def main():
    base_browser = BrowserConfig(
        browser_type="chromium",
        headless=False
    )

    load_more_js = [
            "document.querySelector('button.swal2-confirm.swal2-styled')?.click();"  
        ]
    config = CrawlerRunConfig(
        #Wait for at least 30 items on Hacker News
        js_code=load_more_js,
        cache_mode=CacheMode.BYPASS,
        scan_full_page=True
    )

    async with AsyncWebCrawler(config=base_browser) as crawler:
        result = await crawler.arun(
            url = 'https://www.thsrc.com.tw/',
            config=config
        )
        print(result)

if __name__ == "__main__":
    await main()
# Out:
# [INIT].... → Crawl4AI 0.6.3
# [FETCH]... ↓ https://www.thsrc.com.tw/                                                                            |
# ✓ | ⏱: 2.68s
# [SCRAPE].. ◆ https://www.thsrc.com.tw/                                                                            |
# ✓ | ⏱: 0.06s
# [COMPLETE] ● https://www.thsrc.com.tw/                                                                            |
# ✓ | ⏱: 2.74s
# CrawlResultContainer([CrawlResult(url='https://www.thsrc.com.tw/', html='<!DOCTYPE html><html lang="zh-tw" class=""><head>\n    <!-- Google Tag Manager -->\n    <script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-6M07CCJT7N&amp;cx=c&amp;gtm=45He56u2h1v862560387za200&amp;tag_exp=101509157~103116026~103200004~103233427~103351869~103351871~104684208~104684211~104718208~104839054~104839056~104885889~104885891"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-N92HDF3"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WV8ZBCC"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-KCZ6KF6"></script><script>\n        function loadgtm(w, d, s, l, i) {\n            w[l] = w[l] || []; w[l].push({\n                \'gtm.start\':\n\n                    new Date().getTime(), event: \'gtm.js\'\n            });\n            var f = d.getElementsByTagName(s)[0],\n\n                j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\'; j.async = true; j.src =\n\n                    \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl;\n                    f.parentNode.insertBefore(j, f);\n\n        };\n        window.onload = function () { loadgtm(window, document, \'script\', \'dataLayer\', \'GTM-KCZ6KF6\'); }\n    </script>\n    <!-- End Google Tag Manager -->\n    <meta charset="utf-8">\n    <meta name="theme-color" content="">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="keywords" content="台灣高鐵,Taiwan High Speed Rail">\n    <meta name="description" content="台灣高鐵秉持提供旅客安全、快速的運輸服務為最高原則，以「成為引領進步、創造美好的生活平台」為願景，透過高鐵連接城市間的美好生活，傳遞幸福給每一位乘客。">\n    <meta name="author" content="Taiwan High Speed Rail">\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\n    <link rel="canonical" href="https://www.thsrc.com.tw/ArticleContent/5b93cc99-3a1e-4000-a545-aa5dfe375708">\n    <title>台灣高鐵 | Taiwan High Speed Rail</title>\n    <!-- Facebook META -->\n    <meta property="og:image" content="/event/og-image/logo_1200x400.jpg">\n    <meta property="og:title" content="台灣高鐵 | Taiwan High Speed Rail">\n    <meta property="og:description" content="台灣高鐵秉持提供旅客安全、快速的運輸服務為最高原則，以「成為引領進步、創造美好的生活平台」為願景，透過高鐵連接城市間的美好生活，傳遞幸福給每一位乘客。">\n    <meta property="og:url" content="https://www.thsrc.com.tw/articlecontent/5b93cc99-3a1e-4000-a545-aa5dfe375708">\n    <meta property="og:site_name" content="台灣高鐵企業網站">\n    <meta property="og:type" content="website">\n    <!-- HTML5 Microdata -->\n    <meta itemprop="name" content="台灣高鐵 | Taiwan High Speed Rail">\n    <meta itemprop="description" content="台灣高鐵秉持提供旅客安全、快速的運輸服務為最高原則，以「成為引領進步、創造美好的生活平台」為願景，透過高鐵連接城市間的美好生活，傳遞幸福給每一位乘客。">\n    <meta itemprop="image" content="/event/og-image/logo_1200x400.jpg">\n    <!-- Favicon and touch icons -->\n    <!-- <link rel="apple-touch-icon-precomposed" sizes="144x144" href="/Common/assets/img/logo/logo-144.png">\n    <link rel="apple-touch-icon-precomposed" sizes="114x114" href="/Common/assets/img/logo/logo-114.png">\n    <link rel="apple-touch-icon-precomposed" sizes="72x72" href="/Common/assets/img/logo/logo-72.png">\n    <link rel="apple-touch-icon-precomposed" href="/Common/assets/img/logo/logo-57.png"> -->\n    <link rel="icon" href="/Common/assets/img/logo/favicon.ico">\n    <link rel="shortcut icon" href="/Common/assets/img/logo/57_57.png">\n    <link rel="apple-touch-icon" href="/Common/assets/img/logo/57_57.png" sizes="57x57">\n    <link rel="apple-touch-icon" href="/Common/assets/img/logo/72_72.png" sizes="72x72">\n    <link rel="apple-touch-icon" href="/Common/assets/img/logo/76_76.png" sizes="76x76">\n    <link rel="apple-touch-icon" href="/Common/assets/img/logo/114_114.png" sizes="114x114">\n    <link rel="apple-touch-icon" href="/Common/assets/img/logo/120_120.png" sizes="120x120">\n    < ...
