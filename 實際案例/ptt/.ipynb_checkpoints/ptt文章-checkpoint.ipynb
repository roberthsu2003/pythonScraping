# %% [markdown]
# [ptt網址](https://www.ptt.cc/bbs/Gossiping/index.html)
#
# https://www.ptt.cc/bbs/Gossiping/index.html

# %% [markdown]
# ### 解決進入問題
# 因為有詢問網頁，詢問完後，主機端會傳送一個cookies至瀏灠器，使用chrom開發者工具，查詢cookies內容。
#
# ![](./images/pic1.png)

# %% [markdown]
# ### 取得當日文章

# %%
import requests

headers = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"}
url = "https://www.ptt.cc/bbs/Gossiping/index.html"

#建立detail cookies
jar = requests.cookies.RequestsCookieJar()
jar.set('over18','1',domain='www.ptt.cc',path='/')

response = requests.get(url,headers=headers,cookies=jar)
if response.status_code != 200:
    print("連線有問題",response.status_code)
else:
    print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index38940.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613965128.A.B50.html">Re: [問卦] 中國會被阿拉花瓜嗎？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">LJer</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E4%B8%AD%E5%9C%8B%E6%9C%83%E8%A2%AB%E9%98%BF%E6%8B%89%E8%8A%B1%E7%93%9C%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3ALJer">搜尋看板內 LJer 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613965268.A.899.html">[問卦] 有蝗蟲人的八卦嗎</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">nuggets</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%9C%89%E8%9D%97%E8%9F%B2%E4%BA%BA%E7%9A%84%E5%85%AB%E5%8D%A6%E5%97%8E">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Anuggets">搜尋看板內 nuggets 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613965297.A.167.html">[問卦] 台灣人的交通水平是不是要再教育?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">arnold3</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%8F%B0%E7%81%A3%E4%BA%BA%E7%9A%84%E4%BA%A4%E9%80%9A%E6%B0%B4%E5%B9%B3%E6%98%AF%E4%B8%8D%E6%98%AF%E8%A6%81%E5%86%8D%E6%95%99%E8%82%B2%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aarnold3">搜尋看板內 arnold3 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613965423.A.1CF.html">Re: [問卦] 存股是不是有錢人的陰謀？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">lpbrother</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%AD%98%E8%82%A1%E6%98%AF%E4%B8%8D%E6%98%AF%E6%9C%89%E9%8C%A2%E4%BA%BA%E7%9A%84%E9%99%B0%E8%AC%80%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Alpbrother">搜尋看板內 lpbrother 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">5</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613965471.A.719.html">[新聞] 民進黨內部民調 陳時中滿意度達73.5%成</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">aki1987</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E6%B0%91%E9%80%B2%E9%BB%A8%E5%85%A7%E9%83%A8%E6%B0%91%E8%AA%BF&#43;%E9%99%B3%E6%99%82%E4%B8%AD%E6%BB%BF%E6%84%8F%E5%BA%A6%E9%81%9473.5%25%E6%88%90">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aaki1987">搜尋看板內 aki1987 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613965522.A.C25.html">[問卦] 為啥老人總要年輕人體諒</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">shintrain</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%82%BA%E5%95%A5%E8%80%81%E4%BA%BA%E7%B8%BD%E8%A6%81%E5%B9%B4%E8%BC%95%E4%BA%BA%E9%AB%94%E8%AB%92">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ashintrain">搜尋看板內 shintrain 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613965545.A.1A7.html">Re: [新聞] 路邊攤點「陽春麵不要麵」老闆怒回沒賣！</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">littlest</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E8%B7%AF%E9%82%8A%E6%94%A4%E9%BB%9E%E3%80%8C%E9%99%BD%E6%98%A5%E9%BA%B5%E4%B8%8D%E8%A6%81%E9%BA%B5%E3%80%8D%E8%80%81%E9%97%86%E6%80%92%E5%9B%9E%E6%B2%92%E8%B3%A3%EF%BC%81">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Alittlest">搜尋看板內 littlest 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613965556.A.763.html">[問卦] 神奇寶貝遊戲機ㄧ早就有人排隊？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">yayaya5566</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%A5%9E%E5%A5%87%E5%AF%B6%E8%B2%9D%E9%81%8A%E6%88%B2%E6%A9%9F%E3%84%A7%E6%97%A9%E5%B0%B1%E6%9C%89%E4%BA%BA%E6%8E%92%E9%9A%8A%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ayayaya5566">搜尋看板內 yayaya5566 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/22</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">13</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1605971507.A.5C4.html">[公告] 八卦板板規(2020.11.21)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">arsonlolita</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282020.11.21%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aarsonlolita">搜尋看板內 arsonlolita 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/21</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">31</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613317142.A.ECB.html">[協尋] 2/14早上九點到10點鳳山鳳林路車禍影像</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">mo0219</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;2%2F14%E6%97%A9%E4%B8%8A%E4%B9%9D%E9%BB%9E%E5%88%B010%E9%BB%9E%E9%B3%B3%E5%B1%B1%E9%B3%B3%E6%9E%97%E8%B7%AF%E8%BB%8A%E7%A6%8D%E5%BD%B1%E5%83%8F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Amo0219">搜尋看板內 mo0219 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/14</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">82</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613447816.A.247.html">[協尋] 02/15/08:00~10:00首都客運-電子耳遺失</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">alittlekoa</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;02%2F15%2F08%3A00~10%3A00%E9%A6%96%E9%83%BD%E5%AE%A2%E9%81%8B-%E9%9B%BB%E5%AD%90%E8%80%B3%E9%81%BA%E5%A4%B1">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aalittlekoa">搜尋看板內 alittlekoa 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/16</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">6</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613816855.A.D97.html">[協尋] 2/19 國道3號新竹89公里車禍影像</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">yiwin23</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;2%2F19&#43;%E5%9C%8B%E9%81%933%E8%99%9F%E6%96%B0%E7%AB%B989%E5%85%AC%E9%87%8C%E8%BB%8A%E7%A6%8D%E5%BD%B1%E5%83%8F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ayiwin23">搜尋看板內 yiwin23 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/20</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">9</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613841776.A.D81.html">[公告]-------新春歌唱大賽報名截止線-------   </a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ubcs</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D-------%E6%96%B0%E6%98%A5%E6%AD%8C%E5%94%B1%E5%A4%A7%E8%B3%BD%E5%A0%B1%E5%90%8D%E6%88%AA%E6%AD%A2%E7%B7%9A-------&#43;&#43;&#43;">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/21</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# ### 取得今日目前文章數量
#
# 使用chrom開發工具觀察
#
# ![](./images/pic3.png)
# ![](./images/pic2.png)

# %%
#取得目前日期
import time
today = time.strftime('%m/%d')
#符合ptt日期格式
pttToday = today.lstrip('0')
pttToday
# Out:
# '2/22'

# %%
#取得這頁內目前日期的文章數1
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text,'html.parser')
dateElement = soup.find('div',{"class":"r-ent"}).find('div',{"class":"date"})
dateElement.text
# Out:
# ' 2/22'

# %%
#取得這頁內目前日期的文章數2
r_entElements = soup.find_all('div',{"class":"r-ent"})
amountOfArticle = 0
for element in r_entElements:
    if element.find('div','date').text.strip() == pttToday:
        amountOfArticle += 1
amountOfArticle
# Out:
# 8

# %%
#前一頁文章的網址
pre_url_block = soup.find('div','btn-group btn-group-paging')
pre_url_element = pre_url_block.find_all('a', 'btn wide')[1]
pre_url = pre_url_element['href']
pre_url
# Out:
# '/bbs/Gossiping/index38940.html'

# %%
#取得網站內目前日期的文章數1
