# %% [markdown]
# [ptt網址](https://www.ptt.cc/bbs/Gossiping/index.html)
#
# https://www.ptt.cc/bbs/Gossiping/index.html

# %% [markdown]
# ### 解決進入問題
# 因為有詢問網頁，詢問完後，主機端會傳送一個cookies至瀏灠器，使用chrom開發者工具，查詢cookies內容。
#
# ![](./images/pic1.png)

# %% [markdown]
# ### 取得當日文章

# %%
import requests

headers = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"}
url = "https://www.ptt.cc/bbs/Gossiping/index.html"

#建立detail cookies
jar = requests.cookies.RequestsCookieJar()
jar.set('over18','1',domain='www.ptt.cc',path='/')

response = requests.get(url,headers=headers,cookies=jar)
if response.status_code != 200:
    print("連線有問題",response.status_code)
else:
    print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39005.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1614028470.A.7C7.html">Re: [問卦] 跑去女廁偷舔馬桶蓋的都哪些人?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">GTX9487</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E8%B7%91%E5%8E%BB%E5%A5%B3%E5%BB%81%E5%81%B7%E8%88%94%E9%A6%AC%E6%A1%B6%E8%93%8B%E7%9A%84%E9%83%BD%E5%93%AA%E4%BA%9B%E4%BA%BA%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AGTX9487">搜尋看板內 GTX9487 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">7</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1614028503.A.620.html">Re: [問卦] 在美國,每天吃街頭小吃活得下去嗎?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">naticom</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%9C%A8%E7%BE%8E%E5%9C%8B%2C%E6%AF%8F%E5%A4%A9%E5%90%83%E8%A1%97%E9%A0%AD%E5%B0%8F%E5%90%83%E6%B4%BB%E5%BE%97%E4%B8%8B%E5%8E%BB%E5%97%8E%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Anaticom">搜尋看板內 naticom 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1614028783.A.FFB.html">[問卦] 植物的另一半?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">anothermind</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%A4%8D%E7%89%A9%E7%9A%84%E5%8F%A6%E4%B8%80%E5%8D%8A%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aanothermind">搜尋看板內 anothermind 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1614029088.A.472.html">[問卦] VR A片根本不好用吧？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ffdqfe</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;VR&#43;A%E7%89%87%E6%A0%B9%E6%9C%AC%E4%B8%8D%E5%A5%BD%E7%94%A8%E5%90%A7%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Affdqfe">搜尋看板內 ffdqfe 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1614030385.A.0B8.html">Re: [問卦] 168斷食容易增加膽結石的風險的八卦?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Xaymaca</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;168%E6%96%B7%E9%A3%9F%E5%AE%B9%E6%98%93%E5%A2%9E%E5%8A%A0%E8%86%BD%E7%B5%90%E7%9F%B3%E7%9A%84%E9%A2%A8%E9%9A%AA%E7%9A%84%E5%85%AB%E5%8D%A6%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AXaymaca">搜尋看板內 Xaymaca 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1614030505.A.B83.html">Re: [問卦] 在美國,每天吃街頭小吃活得下去嗎?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">alkahest</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%9C%A8%E7%BE%8E%E5%9C%8B%2C%E6%AF%8F%E5%A4%A9%E5%90%83%E8%A1%97%E9%A0%AD%E5%B0%8F%E5%90%83%E6%B4%BB%E5%BE%97%E4%B8%8B%E5%8E%BB%E5%97%8E%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aalkahest">搜尋看板內 alkahest 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1614030598.A.326.html">Re: [問卦] 50歲失業能做什麼工作？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">pornstar</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;50%E6%AD%B2%E5%A4%B1%E6%A5%AD%E8%83%BD%E5%81%9A%E4%BB%80%E9%BA%BC%E5%B7%A5%E4%BD%9C%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Apornstar">搜尋看板內 pornstar 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/23</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">13</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1605971507.A.5C4.html">[公告] 八卦板板規(2020.11.21)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">arsonlolita</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282020.11.21%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aarsonlolita">搜尋看板內 arsonlolita 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/21</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">31</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613317142.A.ECB.html">[協尋] 2/14早上九點到10點鳳山鳳林路車禍影像</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">mo0219</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;2%2F14%E6%97%A9%E4%B8%8A%E4%B9%9D%E9%BB%9E%E5%88%B010%E9%BB%9E%E9%B3%B3%E5%B1%B1%E9%B3%B3%E6%9E%97%E8%B7%AF%E8%BB%8A%E7%A6%8D%E5%BD%B1%E5%83%8F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Amo0219">搜尋看板內 mo0219 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/14</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">9</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613816855.A.D97.html">[協尋] 2/19 國道3號新竹89公里車禍影像</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">yiwin23</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;2%2F19&#43;%E5%9C%8B%E9%81%933%E8%99%9F%E6%96%B0%E7%AB%B989%E5%85%AC%E9%87%8C%E8%BB%8A%E7%A6%8D%E5%BD%B1%E5%83%8F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ayiwin23">搜尋看板內 yiwin23 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/20</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">24</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613973307.A.A16.html">[公告] 歌唱大賽置底投票 本篇推文投票</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">arsonlolita</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E6%AD%8C%E5%94%B1%E5%A4%A7%E8%B3%BD%E7%BD%AE%E5%BA%95%E6%8A%95%E7%A5%A8&#43;%E6%9C%AC%E7%AF%87%E6%8E%A8%E6%96%87%E6%8A%95%E7%A5%A8">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aarsonlolita">搜尋看板內 arsonlolita 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/22</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">17</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1613447816.A.247.html">[協尋] 02/15/08:00~10:00首都客運-電子耳遺失</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">alittlekoa</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;02%2F15%2F08%3A00~10%3A00%E9%A6%96%E9%83%BD%E5%AE%A2%E9%81%8B-%E9%9B%BB%E5%AD%90%E8%80%B3%E9%81%BA%E5%A4%B1">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aalittlekoa">搜尋看板內 alittlekoa 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/16</div>
# 				<div class="mark">M</div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %% [markdown]
# ### 取得今日目前文章數量
#
# 使用chrom開發工具觀察
#
# ![](./images/pic3.png)
# ![](./images/pic2.png)

# %%
#取得目前日期
import time
today = time.strftime('%m/%d')
#符合ptt日期格式
pttToday = today.lstrip('0')
pttToday
# Out:
# '2/23'

# %%
#取得這頁內目前日期的文章數1
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text,'html.parser')
dateElement = soup.find('div',{"class":"r-ent"}).find('div',{"class":"date"})
dateElement.text
# Out:
# ' 2/23'

# %%
#取得本頁內目前日期的文章數2
r_entElements = soup.find_all('div',{"class":"r-ent"})
amountOfArticle = 0
for element in r_entElements:
    if element.find('div','date').text.strip() == pttToday:
        amountOfArticle += 1
amountOfArticle
# Out:
# 7

# %%
#前一頁文章的網址
pre_url_block = soup.find('div','btn-group btn-group-paging')
pre_url_element = pre_url_block.find_all('a', 'btn wide')[1]
pre_url = pre_url_element['href']
pre_url
# Out:
# '/bbs/Gossiping/index39005.html'

# %%
#取得本頁面內目前日期所有文章內容
articles = [] #儲存文章內容
r_entElements = soup.find_all('div',{"class":"r-ent"})
for element in r_entElements:
    if element.find('div','date').text.strip() == pttToday:
        pushNum = element.find('div','nrec').get_text().strip()  #取得推文數
        titleElement = element.find('div','title') #取得推文元素
        title = titleElement.get_text().strip() #取得title
        titleLink = titleElement.a['href'] #取得文章連結網址
        author = element.find('div','author').text #取得作者        
        oneArticle = {}
        oneArticle['推文數'] = int(pushNum) if pushNum!="" else 0 #如果推文數是空字串則傳回0
        oneArticle['文章標題'] = title
        oneArticle['文章連結'] = titleLink
        oneArticle['作者'] = author
        articles.append(oneArticle)
articles
# Out:
#  Re: [問卦] 跑去女廁偷舔馬桶蓋的都哪些人? /bbs/Gossiping/M.1614028470.A.7C7.html GTX9487
# 7 Re: [問卦] 在美國,每天吃街頭小吃活得下去嗎? /bbs/Gossiping/M.1614028503.A.620.html naticom
# 1 [問卦] 植物的另一半? /bbs/Gossiping/M.1614028783.A.FFB.html anothermind
# 4 [問卦] VR A片根本不好用吧？ /bbs/Gossiping/M.1614029088.A.472.html ffdqfe
#  Re: [問卦] 168斷食容易增加膽結石的風險的八卦? /bbs/Gossiping/M.1614030385.A.0B8.html Xaymaca
# 2 Re: [問卦] 在美國,每天吃街頭小吃活得下去嗎? /bbs/Gossiping/M.1614030505.A.B83.html alkahest
#  Re: [問卦] 50歲失業能做什麼工作？ /bbs/Gossiping/M.1614030598.A.326.html pornstar
# [{'推文數': 0,
#   '文章標題': 'Re: [問卦] 跑去女廁偷舔馬桶蓋的都哪些人?',
#   '文章連結': '/bbs/Gossiping/M.1614028470.A.7C7.html',
#   '作者': 'GTX9487'},
#  {'推文數': 7,
#   '文章標題': 'Re: [問卦] 在美國,每天吃街頭小吃活得下去嗎?',
#   '文章連結': '/bbs/Gossiping/M.1614028503.A.620.html',
#   '作者': 'naticom'},
#  {'推文數': 1,
#   '文章標題': '[問卦] 植物的另一半?',
#   '文章連結': '/bbs/Gossiping/M.1614028783.A.FFB.html',
#   '作者': 'anothermind'},
#  {'推文數': 4,
#   '文章標題': '[問卦] VR A片根本不好用吧？',
#   '文章連結': '/bbs/Gossiping/M.1614029088.A.472.html',
#   '作者': 'ffdqfe'},
#  {'推文數': 0,
#   '文章標題': 'Re: [問卦] 168斷食容易增加膽結石的風險的八卦?',
#   '文章連結': '/bbs/Gossiping/M.1614030385.A.0B8.html',
#   '作者': 'Xaymaca'},
#  {'推文數': 2,
#   '文章標題': 'Re: [問卦] 在美國,每天吃街頭小吃活得下去嗎?',
#   '文章連結': '/bbs/Gossiping/M.1614030505.A.B83.html',
#   '作者': 'alkahest'},
#  {'推文數': 0,
#   '文章標題': 'Re: [問卦] 50歲失業能做什麼工作？',
#   '文章連結': '/bbs/Gossiping/M.1614030598.A.326.html',
#   '作者': 'pornstar'}]

# %%
#取所有頁面內目前日期所有文章內容
#將取得一頁內容的程式成為函式，並傳出一頁的內容,有無前面連結
def contentOfOnePage(URL):
    headers = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.182 Safari/537.36"}
    
    #建立detail cookies
    jar = requests.cookies.RequestsCookieJar()
    jar.set('over18','1',domain='www.ptt.cc',path='/')

    response = requests.get(URL,headers=headers,cookies=jar)
    if response.status_code != 200:
        print("連線有問題",response.status_code)
        return None
    else:
        print(response.text)
    
    soup = BeautifulSoup(response.text,'html.parser')
    dateElement = soup.find('div',{"class":"r-ent"}).find('div',{"class":"date"})
    toadyDate = dateElement.text
    
    pre_url_block = soup.find('div','btn-group btn-group-paging')
    pre_url_element = pre_url_block.find_all('a', 'btn wide')[1]
    pre_url = pre_url_element['href']
    
    articlesOfpage = []
    
    for element in r_entElements:
        if element.find('div','date').text.strip() == pttToday:
            pushNum = element.find('div','nrec').get_text().strip()  #取得推文數
            titleElement = element.find('div','title') #取得推文元素
            title = titleElement.get_text().strip() #取得title
            titleLink = titleElement.a['href'] #取得文章連結網址
            author = element.find('div','author').text #取得作者        
            oneArticle = {}
            oneArticle['推文數'] = int(pushNum) if pushNum!="" else 0 #如果推文數是空字串則傳回0
            oneArticle['文章標題'] = title
            oneArticle['文章連結'] = titleLink
            oneArticle['作者'] = author
            articlesOfpage.append(oneArticle)
        else:
            pre_url = None
            break
            
    return articlesOfpage, pre_url  #傳出tuple,前面為所有文章,後面為前一頁網址,如果本日文章已經結束,則傳回None
